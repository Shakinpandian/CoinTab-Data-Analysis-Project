# %% [markdown]
# ## COINTAB PRIVATE LIMITED - DATA ANALYSIS PROJECT

# %% [markdown]
# ## Importing a libaries

# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Loading a data

# %%
Order=pd.read_excel("Company_X_Order_Report.xlsx")
invoice=pd.read_excel("Courier_Company_Invoice.xlsx")
sku=pd.read_excel("Company_X_SKU_Master.xlsx")
X_post=pd.read_excel("Company_X_Pincode_Zones.xlsx")

# %% [markdown]
# ## Merge function

# %%
# Combining a company_X_Order_Report with Courier_Company_invoice by using merge function 
# For merging a data table, i have used a "Order_ID" feature and User-defined variable "o"
O=pd.merge(Order,invoice,on="Order_ID",how="right")

# To combine a user_defined variable "o" of a new data table with Company_X_SKU_Master table by using merge fuction
#For merging a data table, i have used a "SKU" feature and User-defined variable "Ex"
Ex=pd.merge(O,sku,on="SKU",how="left")

# To combine a user_defined variable "Ex" of a new data table with Company_X_Pincode_Zone table by using merge fuction
#For merging a data table, i have used a Customer_Pincode feature and User-defined variable "Ones"
Ones=pd.merge(Ex,X_post,how="inner",on="Customer_Pincode")

# %%
Ones
# Out:
#        Order_ID            SKU  Order_Qty       AWB Code  Charged Weight  \
# 0    2001806232  8904223818645          6  1091117222124             1.3
# 1    2001806232  8904223819147          2  1091117222124             1.3
# 2    2001806273  8904223819017          1  1091117222194             1.0
# 3    2001806273  8904223818706          1  1091117222194             1.0
# 4    2001806273  8904223818942          1  1091117222194             1.0
# ..          ...            ...        ...            ...             ...
# 562  2001809383  8904223818706          1  1091117614452             0.5
# 563  2001809383  8904223818850          1  1091117614452             0.5
# 564  2001809383  8904223819468          1  1091117614452             0.5
# 565  2001820978  8904223815859          1  1091120922803             0.5
# 566  2001820978  8904223817501          1  1091120922803             0.5
#
#      Warehouse_Pincode_x  Customer_Pincode Zone_x         Type_of_Shipment  \
# ...

# %%
# Rename the columns name as per require:
Ones.rename(columns={"Charged Weight":"Charged_Weight","Warehouse_Pincode_x":"Company_Warehouse_Pincode",
                     "Customer_Pincode":"Company_Customer_Pincode","Zone_x":"Company_Zone",
                     "Warehouse_Pincode_y":"X_Warehouse_Pincode","Zone_y":"X_Zone","Weight (g)":"Weight_(g)"},inplace=True)
Ones.rename(columns={"Company_Zone":"Delivery_Zone_charged_by_Courier_Company","X_Zone":"Delivery_Zone_as_per_X"},inplace=True)
Ones.rename(columns={"Charged_Weight":"Total_weight_as_per_Courier_Company_(KG)"},inplace=True)

# %%
Ones
# Out:
#        Order_ID       AWB Code  Total_weight_as_per_Courier_Company_(KG)  \
# 0    2001806232  1091117222124                                       1.3
# 1    2001806232  1091117222124                                       1.3
# 2    2001806273  1091117222194                                       1.0
# 3    2001806273  1091117222194                                       1.0
# 4    2001806273  1091117222194                                       1.0
# ..          ...            ...                                       ...
# 562  2001809383  1091117614452                                       0.5
# 563  2001809383  1091117614452                                       0.5
# 564  2001809383  1091117614452                                       0.5
# 565  2001820978  1091120922803                                       0.5
# 566  2001820978  1091120922803                                       0.5
#
#     Delivery_Zone_charged_by_Courier_Company Delivery_Zone_as_per_X  \
# ...

# %%
Ones.columns
# Out:
# Index(['Order_ID', 'AWB Code', 'Total_weight_as_per_Courier_Company_(KG)',
#        'Delivery_Zone_charged_by_Courier_Company', 'Delivery_Zone_as_per_X',
#        'Total_weight_as_per_X(Kg)', 'Weight_slab_as_per_X_(KG)',
#        'Weight_slab_charged_by_Courier_Company_(KG)',
#        'Expected_Charge_as_per_X_(Rs.)',
#        'Charges_Billed_by_Courier_Company_(Rs.)',
#        'Difference_Between_Expected_Charges_and_Billed_Charges_(Rs.)'],
#       dtype='object')

# %%
# Calculation:
   # Multiplication of Weight(g)*Order_qty, to find out the 
   #Convertion of gram to Kg of the total weight as per X company
Ones["Total_weight_as_per_X(g)"]=Ones["Order_Qty"]*Ones["Weight_(g)"]
Ones["Total_weight_as_per_X(Kg)"]=Ones["Total_weight_as_per_X(g)"]/1000

# %%
Ones
# Out:
#        Order_ID       AWB Code  Total_weight_as_per_Courier_Company_(KG)  \
# 0    2001806232  1091117222124                                       1.3
# 1    2001806232  1091117222124                                       1.3
# 2    2001806273  1091117222194                                       1.0
# 3    2001806273  1091117222194                                       1.0
# 4    2001806273  1091117222194                                       1.0
# ..          ...            ...                                       ...
# 562  2001809383  1091117614452                                       0.5
# 563  2001809383  1091117614452                                       0.5
# 564  2001809383  1091117614452                                       0.5
# 565  2001820978  1091120922803                                       0.5
# 566  2001820978  1091120922803                                       0.5
#
#     Delivery_Zone_charged_by_Courier_Company Delivery_Zone_as_per_X  \
# ...

# %% [markdown]
# ## IF condition- To find out the weight_slab_as_per_X_company

# %%
condition=[(Ones["Total_weight_as_per_X(Kg)"]<=0.500),
          (Ones["Total_weight_as_per_X(Kg)"]>0.500)&(Ones["Total_weight_as_per_X(Kg)"]<=1),
          (Ones["Total_weight_as_per_X(Kg)"]>1)&(Ones["Total_weight_as_per_X(Kg)"]<=1.5),
          (Ones["Total_weight_as_per_X(Kg)"]>1.5)&(Ones["Total_weight_as_per_X(Kg)"]<=2),
          (Ones["Total_weight_as_per_X(Kg)"]>2)&(Ones["Total_weight_as_per_X(Kg)"]<=2.5),
          (Ones["Total_weight_as_per_X(Kg)"]>2.5)&(Ones["Total_weight_as_per_X(Kg)"]<=3),
          (Ones["Total_weight_as_per_X(Kg)"]>3)&(Ones["Total_weight_as_per_X(Kg)"]<=3.5),
          (Ones["Total_weight_as_per_X(Kg)"]>3.5)&(Ones["Total_weight_as_per_X(Kg)"]<=4)]

# %%
value=[0.5,1,1.5,2,2.5,3,3.5,4]

# %%
Ones["Weight_slab_as_per_X_(KG)"]=np.select(condition,value)

# %%
Ones
# Out:
#        Order_ID            SKU  Order_Qty       AWB Code  Charged_Weight  \
# 0    2001806232  8904223818645          6  1091117222124             1.3
# 1    2001806232  8904223819147          2  1091117222124             1.3
# 2    2001806273  8904223819017          1  1091117222194             1.0
# 3    2001806273  8904223818706          1  1091117222194             1.0
# 4    2001806273  8904223818942          1  1091117222194             1.0
# ..          ...            ...        ...            ...             ...
# 562  2001809383  8904223818706          1  1091117614452             0.5
# 563  2001809383  8904223818850          1  1091117614452             0.5
# 564  2001809383  8904223819468          1  1091117614452             0.5
# 565  2001820978  8904223815859          1  1091120922803             0.5
# 566  2001820978  8904223817501          1  1091120922803             0.5
#
#      Company_Warehouse_Pincode  Company_Customer_Pincode Company_Zone  \
# ...

# %% [markdown]
# ## If condition- To find out the Weight_slab_charged_by_Courier_Company_(KG)

# %%
conditions=[(Ones["Total_weight_as_per_Courier_Company_(KG)"]<=0.500),
          (Ones["Total_weight_as_per_Courier_Company_(KG)"]>0.500)&(Ones["Total_weight_as_per_Courier_Company_(KG)"]<=1),
          (Ones["Total_weight_as_per_Courier_Company_(KG)"]>1)&(Ones["Total_weight_as_per_Courier_Company_(KG)"]<=1.5),
          (Ones["Total_weight_as_per_Courier_Company_(KG)"]>1.5)&(Ones["Total_weight_as_per_Courier_Company_(KG)"]<=2),
          (Ones["Total_weight_as_per_Courier_Company_(KG)"]>2)&(Ones["Total_weight_as_per_Courier_Company_(KG)"]<=2.5),
          (Ones["Total_weight_as_per_Courier_Company_(KG)"]>2.5)&(Ones["Total_weight_as_per_Courier_Company_(KG)"]<=3),
          (Ones["Total_weight_as_per_Courier_Company_(KG)"]>3)&(Ones["Total_weight_as_per_Courier_Company_(KG)"]<=3.5),
          (Ones["Total_weight_as_per_Courier_Company_(KG)"]>3.5)&(Ones["Total_weight_as_per_Courier_Company_(KG)"]<=4)]

# %%
value=[0.5,1,1.5,2,2.5,3,3.5,4]

# %%
Ones["Weight_slab_charged_by_Courier_Company_(KG)"]=np.select(conditions,value)

# %%
Ones
# Out:
#        Order_ID            SKU  Order_Qty       AWB Code  \
# 0    2001806232  8904223818645          6  1091117222124
# 1    2001806232  8904223819147          2  1091117222124
# 2    2001806273  8904223819017          1  1091117222194
# 3    2001806273  8904223818706          1  1091117222194
# 4    2001806273  8904223818942          1  1091117222194
# ..          ...            ...        ...            ...
# 562  2001809383  8904223818706          1  1091117614452
# 563  2001809383  8904223818850          1  1091117614452
# 564  2001809383  8904223819468          1  1091117614452
# 565  2001820978  8904223815859          1  1091120922803
# 566  2001820978  8904223817501          1  1091120922803
#
#      Total_weight_as_per_Courier_Company_(KG)  Company_Warehouse_Pincode  \
# 0                                         1.3                     121003
# 1                                         1.3                     121003
# ...

# %% [markdown]
# ## If condition- To find out the Expected_Charge_as_per_X_(Rs.)

# %%
conditionss=[(Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_as_per_X"]=="b")&
             (Ones["Weight_slab_as_per_X_(KG)"]==0.5),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_as_per_X"]=="b")&
             (Ones["Weight_slab_as_per_X_(KG)"]==1.0),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_as_per_X"]=="b")&
             (Ones["Weight_slab_as_per_X_(KG)"]==1.5),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_as_per_X"]=="d")&
             (Ones["Weight_slab_as_per_X_(KG)"]==0.5),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_as_per_X"]=="d")&
             (Ones["Weight_slab_as_per_X_(KG)"]==1.0),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_as_per_X"]=="d")&
             (Ones["Weight_slab_as_per_X_(KG)"]==1.5),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_as_per_X"]=="e")&
             (Ones["Weight_slab_as_per_X_(KG)"]==0.5),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_as_per_X"]=="e")&
             (Ones["Weight_slab_as_per_X_(KG)"]==1.0),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_as_per_X"]=="e")&
             (Ones["Weight_slab_as_per_X_(KG)"]==1.5),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_as_per_X"]=="b")&
             (Ones["Weight_slab_as_per_X_(KG)"]==0.5),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_as_per_X"]=="b")&
             (Ones["Weight_slab_as_per_X_(KG)"]==1.0),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_as_per_X"]=="b")&
             (Ones["Weight_slab_as_per_X_(KG)"]==1.5),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_as_per_X"]=="d")&
             (Ones["Weight_slab_as_per_X_(KG)"]==0.5),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_as_per_X"]=="d")&
             (Ones["Weight_slab_as_per_X_(KG)"]==1.0),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_as_per_X"]=="d")&
             (Ones["Weight_slab_as_per_X_(KG)"]==1.5),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_as_per_X"]=="e")&
             (Ones["Weight_slab_as_per_X_(KG)"]==0.5),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_as_per_X"]=="e")&
             (Ones["Weight_slab_as_per_X_(KG)"]==1.0),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_as_per_X"]=="e")&
             (Ones["Weight_slab_as_per_X_(KG)"]==1.5)]

# %%
valuess=[(Ones["Billing_Amount (Rs.)"]+33),(Ones["Billing_Amount (Rs.)"]+61.3),(Ones["Billing_Amount (Rs.)"]+89.6),
         (Ones["Billing_Amount (Rs.)"]+45.4),(Ones["Billing_Amount (Rs.)"]+90.2),(Ones["Billing_Amount (Rs.)"]+135),
        (Ones["Billing_Amount (Rs.)"]+56.6),(Ones["Billing_Amount (Rs.)"]+112.1),(Ones["Billing_Amount (Rs.)"]+167.6),
        (Ones["Billing_Amount (Rs.)"]+45.4),(Ones["Billing_Amount (Rs.)"]+110.1),(Ones["Billing_Amount (Rs.)"]+166.7),
         (Ones["Billing_Amount (Rs.)"]+86.7),(Ones["Billing_Amount (Rs.)"]+176.3),(Ones["Billing_Amount (Rs.)"]+265.9),
         (Ones["Billing_Amount (Rs.)"]+107.3),(Ones["Billing_Amount (Rs.)"]+218.3),(Ones["Billing_Amount (Rs.)"]+329.3)]

# %%
Ones["Weight_slab_as_per_X_(KG)"].value_counts()
# Out:
# 0.5    554
# 1.0     12
# 1.5      1
# Name: Weight_slab_as_per_X_(KG), dtype: int64

# %%
Ones["Delivery_Zone_as_per_X"].value_counts()
# Out:
# b    397
# d    136
# e     34
# Name: Delivery_Zone_as_per_X, dtype: int64

# %%
Ones["Type_of_Shipment"].value_counts()
# Out:
# Forward charges            517
# Forward and RTO charges     50
# Name: Type_of_Shipment, dtype: int64

# %%
Ones["Expected_Charge_as_per_X_(Rs.)"]=np.select(conditionss,valuess)

# %%
Ones
# Out:
#        Order_ID            SKU  Order_Qty       AWB Code  \
# 0    2001806232  8904223818645          6  1091117222124
# 1    2001806232  8904223819147          2  1091117222124
# 2    2001806273  8904223819017          1  1091117222194
# 3    2001806273  8904223818706          1  1091117222194
# 4    2001806273  8904223818942          1  1091117222194
# ..          ...            ...        ...            ...
# 562  2001809383  8904223818706          1  1091117614452
# 563  2001809383  8904223818850          1  1091117614452
# 564  2001809383  8904223819468          1  1091117614452
# 565  2001820978  8904223815859          1  1091120922803
# 566  2001820978  8904223817501          1  1091120922803
#
#      Total_weight_as_per_Courier_Company_(KG)  Company_Warehouse_Pincode  \
# 0                                         1.3                     121003
# 1                                         1.3                     121003
# ...

# %% [markdown]
# ## If condition- To find out the Charges_Billed_by_Courier_Company_(Rs.)

# %%
con=[(Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="b")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==0.5),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="b")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==1.0),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="b")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==1.5),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="b")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==2),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="b")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==2.5),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="b")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==3),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="d")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==0.5),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="d")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==1.0),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="d")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==1.5),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="d")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==2),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="d")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==2.5),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="d")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==3),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="e")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==0.5),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="e")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==1.0),
             (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="e")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==1.5),
              (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="e")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==2),
              (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="e")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==2.5),
              (Ones["Type_of_Shipment"]=="Forward charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="e")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==3),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="b")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==0.5),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="b")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==1.0),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="b")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==1.5),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="b")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==2),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="b")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==2.5),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="b")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==3),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="d")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==0.5),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="d")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==1.0),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="d")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==1.5), 
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="d")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==2), 
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="d")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==2.5),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="d")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==3),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="e")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==0.5),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="e")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==1.0),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="e")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==1.5),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="e")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==2),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="e")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==2.5),
             (Ones["Type_of_Shipment"]=="Forward and RTO charges")&(Ones["Delivery_Zone_charged_by_Courier_Company"]=="e")&
             (Ones["Weight_slab_charged_by_Courier_Company_(KG)"]==3)]

# %%
val=[(Ones["Billing_Amount (Rs.)"]+33),(Ones["Billing_Amount (Rs.)"]+61.3),(Ones["Billing_Amount (Rs.)"]+89.6),(Ones["Billing_Amount (Rs.)"]+117.9),(Ones["Billing_Amount (Rs.)"]+146.2),(Ones["Billing_Amount (Rs.)"]+174.5),
(Ones["Billing_Amount (Rs.)"]+45.4),(Ones["Billing_Amount (Rs.)"]+90.2),(Ones["Billing_Amount (Rs.)"]+135),(Ones["Billing_Amount (Rs.)"]+179.8),(Ones["Billing_Amount (Rs.)"]+224.6),(Ones["Billing_Amount (Rs.)"]+269.4),
(Ones["Billing_Amount (Rs.)"]+56.6),(Ones["Billing_Amount (Rs.)"]+112.1),(Ones["Billing_Amount (Rs.)"]+167.6),(Ones["Billing_Amount (Rs.)"]+223.1),(Ones["Billing_Amount (Rs.)"]+278.6),(Ones["Billing_Amount (Rs.)"]+334.1),
(Ones["Billing_Amount (Rs.)"]+45.4),(Ones["Billing_Amount (Rs.)"]+110.1),(Ones["Billing_Amount (Rs.)"]+166.7),(Ones["Billing_Amount (Rs.)"]+223.3),(Ones["Billing_Amount (Rs.)"]+279.9),(Ones["Billing_Amount (Rs.)"]+336.5),
(Ones["Billing_Amount (Rs.)"]+86.7),(Ones["Billing_Amount (Rs.)"]+176.3),(Ones["Billing_Amount (Rs.)"]+265.9),(Ones["Billing_Amount (Rs.)"]+355.5),(Ones["Billing_Amount (Rs.)"]+445.1),(Ones["Billing_Amount (Rs.)"]+534.7),
(Ones["Billing_Amount (Rs.)"]+107.3),(Ones["Billing_Amount (Rs.)"]+218.3),(Ones["Billing_Amount (Rs.)"]+329.3),(Ones["Billing_Amount (Rs.)"]+440.3),(Ones["Billing_Amount (Rs.)"]+551.3),(Ones["Billing_Amount (Rs.)"]+662.3)]

# %%
Ones["Weight_slab_charged_by_Courier_Company_(KG)"].value_counts()
# Out:
# 1.0    261
# 1.5    106
# 0.5     78
# 2.0     52
# 2.5     41
# 3.0     27
# 0.0      2
# Name: Weight_slab_charged_by_Courier_Company_(KG), dtype: int64

# %%
Ones["Delivery_Zone_charged_by_Courier_Company"].value_counts()
# Out:
# d    454
# b    108
# e      5
# Name: Delivery_Zone_charged_by_Courier_Company, dtype: int64

# %%
Ones["Charges_Billed_by_Courier_Company_(Rs.)"]=np.select(con,val)

# %%
Ones
# Out:
#        Order_ID            SKU  Order_Qty       AWB Code  \
# 0    2001806232  8904223818645          6  1091117222124
# 1    2001806232  8904223819147          2  1091117222124
# 2    2001806273  8904223819017          1  1091117222194
# 3    2001806273  8904223818706          1  1091117222194
# 4    2001806273  8904223818942          1  1091117222194
# ..          ...            ...        ...            ...
# 562  2001809383  8904223818706          1  1091117614452
# 563  2001809383  8904223818850          1  1091117614452
# 564  2001809383  8904223819468          1  1091117614452
# 565  2001820978  8904223815859          1  1091120922803
# 566  2001820978  8904223817501          1  1091120922803
#
#      Total_weight_as_per_Courier_Company_(KG)  Company_Warehouse_Pincode  \
# 0                                         1.3                     121003
# 1                                         1.3                     121003
# ...

# %% [markdown]
# ## Calculation of Difference_Between_Expected_Charges_and_Billed_Charges_(Rs.)

# %%
Ones["Difference_Between_Expected_Charges_and_Billed_Charges_(Rs.)"]=
Ones["Expected_Charge_as_per_X_(Rs.)"]-Ones["Charges_Billed_by_Courier_Company_(Rs.)"]

# %%
Ones
# Out:
#        Order_ID            SKU  Order_Qty       AWB Code  \
# 0    2001806232  8904223818645          6  1091117222124
# 1    2001806232  8904223819147          2  1091117222124
# 2    2001806273  8904223819017          1  1091117222194
# 3    2001806273  8904223818706          1  1091117222194
# 4    2001806273  8904223818942          1  1091117222194
# ..          ...            ...        ...            ...
# 562  2001809383  8904223818706          1  1091117614452
# 563  2001809383  8904223818850          1  1091117614452
# 564  2001809383  8904223819468          1  1091117614452
# 565  2001820978  8904223815859          1  1091120922803
# 566  2001820978  8904223817501          1  1091120922803
#
#      Total_weight_as_per_Courier_Company_(KG)  Company_Warehouse_Pincode  \
# 0                                         1.3                     121003
# 1                                         1.3                     121003
# ...

# %% [markdown]
# ## Delete the unwanted columns as per report:

# %%
REPORT=Ones

# %%
dele=["SKU","Order_Qty","Company_Warehouse_Pincode","Company_Customer_Pincode","Type_of_Shipment",
      "Billing_Amount (Rs.)","Weight_(g)","X_Warehouse_Pincode","Total_weight_as_per_X(g)"]

# %%
for i in dele:
    REPORT.drop([i],inplace=True,axis=1)

# %%
REPORT
# Out:
#        Order_ID       AWB Code  Total_weight_as_per_Courier_Company_(KG)  \
# 0    2001806232  1091117222124                                       1.3
# 1    2001806232  1091117222124                                       1.3
# 2    2001806273  1091117222194                                       1.0
# 3    2001806273  1091117222194                                       1.0
# 4    2001806273  1091117222194                                       1.0
# ..          ...            ...                                       ...
# 562  2001809383  1091117614452                                       0.5
# 563  2001809383  1091117614452                                       0.5
# 564  2001809383  1091117614452                                       0.5
# 565  2001820978  1091120922803                                       0.5
# 566  2001820978  1091120922803                                       0.5
#
#     Delivery_Zone_charged_by_Courier_Company Delivery_Zone_as_per_X  \
# ...

# %% [markdown]
# ## Arrange the features as per report submission:

# %%
FINAL_REPORT=REPORT[["Order_ID","AWB Code","Total_weight_as_per_X(Kg)","Weight_slab_as_per_X_(KG)",
                     "Total_weight_as_per_Courier_Company_(KG)","Weight_slab_charged_by_Courier_Company_(KG)",
                     "Delivery_Zone_as_per_X","Delivery_Zone_charged_by_Courier_Company","Expected_Charge_as_per_X_(Rs.)",
                    "Charges_Billed_by_Courier_Company_(Rs.)","Difference_Between_Expected_Charges_and_Billed_Charges_(Rs.)"]]

# %%
submission=FINAL_REPORT

# %%
Submission
# Out:
#        Order_ID       AWB Code  Total_weight_as_per_X(Kg)  \
# 0    2001806232  1091117222124                      0.822
# 1    2001806232  1091117222124                      0.480
# 2    2001806273  1091117222194                      0.115
# 3    2001806273  1091117222194                      0.127
# 4    2001806273  1091117222194                      0.133
# ..          ...            ...                        ...
# 562  2001809383  1091117614452                      0.127
# 563  2001809383  1091117614452                      0.240
# 564  2001809383  1091117614452                      0.240
# 565  2001820978  1091120922803                      0.165
# 566  2001820978  1091120922803                      0.350
#
#      Weight_slab_as_per_X_(KG)  Total_weight_as_per_Courier_Company_(KG)  \
# 0                          1.0                                       1.3
# 1                          0.5                                       1.3
# ...

# %%
# If condition- To find out the "Total orders where X has been correctly charged"
cK=[(Submission["Charges_Billed_by_Courier_Company_(Rs.)"])==(Submission["Expected_Charge_as_per_X_(Rs.)"])]
VO=[Submission["Expected_Charge_as_per_X_(Rs.)"]]
Submission["Total orders where X has been correctly charged"]=np.select(cK,VO)


# If condition- To find out the "Total Orders where X has been overchargeds"
K=[(Submission["Charges_Billed_by_Courier_Company_(Rs.)"])>(Submission["Expected_Charge_as_per_X_(Rs.)"])]
O=[Submission["Difference_Between_Expected_Charges_and_Billed_Charges_(Rs.)"]]
Submission["Total Orders where X has been overchargeds"]=np.select(K,O)


# If condition- To find out the Total Orders where X has been undercharged"
Kw=[(Submission["Charges_Billed_by_Courier_Company_(Rs.)"])<(Submission["Expected_Charge_as_per_X_(Rs.)"])]
Ow=[Submission["Difference_Between_Expected_Charges_and_Billed_Charges_(Rs.)"]]
Submission["Total Orders where X has been undercharged"]=np.select(Kw,Ow)

# %%
Submission
# Out:
#        Order_ID       AWB Code  Total_weight_as_per_X(Kg)  \
# 0    2001806232  1091117222124                      0.822
# 1    2001806232  1091117222124                      0.480
# 2    2001806273  1091117222194                      0.115
# 3    2001806273  1091117222194                      0.127
# 4    2001806273  1091117222194                      0.133
# ..          ...            ...                        ...
# 562  2001809383  1091117614452                      0.127
# 563  2001809383  1091117614452                      0.240
# 564  2001809383  1091117614452                      0.240
# 565  2001820978  1091120922803                      0.165
# 566  2001820978  1091120922803                      0.350
#
#      Weight_slab_as_per_X_(KG)  Total_weight_as_per_Courier_Company_(KG)  \
# 0                          1.0                                       1.3
# 1                          0.5                                       1.3
# ...

# %% [markdown]
# ## Converting the python file into Excel file

# %%
Submission.to_excel("C:\\Users\\SHAKIN PANDIAN\\Submission.xlsx")
